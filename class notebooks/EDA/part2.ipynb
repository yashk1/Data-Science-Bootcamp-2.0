# %%
import pandas as pd

# %%
df = pd.read_csv("clean_google_data.csv")
df.head(2)
# Out:
#                                               app        category  rating
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1  \
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    reviews     size  installs  type  price content_rating
# 0      159  19000.0     10000  Free    0.0       Everyone  \
# 1      967  14000.0    500000  Free    0.0       Everyone
#
#                       genres last_updated current_ver android_ver  year
# 0               Art & Design   2018-01-07       1.0.0      4.0.3   2018  \
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0      4.0.3   2018
#
#    month  day
# 0      1    7
# 1      1   15

# %%
df.tail()
# Out:
#                                                  app             category
# 10835                               Sya9a Maroc - FR               FAMILY  \
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        rating  reviews     size  installs  type  price content_rating
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone  \
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   genres last_updated         current_ver android_ver  year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   app             10840 non-null  object
#  1   category        10840 non-null  object
#  2   rating          9366 non-null   float64
#  3   reviews         10840 non-null  int64
#  4   size            9145 non-null   float64
#  5   installs        10840 non-null  int64
#  6   type            10839 non-null  object
#  7   price           10840 non-null  float64
#  8   content_rating  10840 non-null  object
#  9   genres          10840 non-null  object
#  10  last_updated    10840 non-null  object
#  11  current_ver     10832 non-null  object
#  12  android_ver     9476 non-null   object
#  13  year            10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  day             10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.columns
# Out:
# Index(['app', 'category', 'rating', 'reviews', 'size', 'installs', 'type',
#        'price', 'content_rating', 'genres', 'last_updated', 'current_ver',
#        'android_ver', 'year', 'month', 'day'],
#       dtype='object')

# %% [markdown]
# ### Types of analysis
# 1. Univariate
# 2. Bi variate -> 2 cols
# 3. Multi variate -> multiple cols

# %%
df[df.duplicated()]
# Out:
#                                                    app      category  rating
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2  \
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %% [markdown]
# Duplicate wrt to one col

# %%
df[df.duplicated('app')]
# Out:
#                                       app       category  rating  reviews
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805  \
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10714                  FarmersOnly Dating         DATING     3.0     1145
# 10719  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10729                         FP Notebook        MEDICAL     4.5      410
# 10752      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10767                                AAFP        MEDICAL     3.8       63
#
#           size  installs  type  price content_rating         genres
# ...

# %%
print(f'{len(df)} rows before dropping duplicates from App')
df = df.drop_duplicates(subset = ['app'], keep = 'first')

print(f'{len(df)} rows after dropping duplicates from App')
df.head()
# Out:
# 10840 rows before dropping duplicates from App
# 9659 rows after dropping duplicates from App
#                                                  app        category  rating
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    reviews     size  installs  type  price content_rating
# 0      159  19000.0     10000  Free    0.0       Everyone  \
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
# ...

# %%
numeric_features = [col for col in df.columns if df[col].dtype != "O"]

categorical_features = [col for col in df.columns if df[col].dtype == "O"]

print(f'Numeric -> {numeric_features}')

print(f'Categorical -> {categorical_features}')
# Out:
# Numeric -> ['rating', 'reviews', 'size', 'installs', 'price', 'year', 'month', 'day']
# Categorical -> ['app', 'category', 'type', 'content_rating', 'genres', 'last_updated', 'current_ver', 'android_ver']

# %%
df[numeric_features]
# Out:
#        rating  reviews     size  installs  price  year  month  day
# 0         4.1      159  19000.0     10000    0.0  2018      1    7
# 1         3.9      967  14000.0    500000    0.0  2018      1   15
# 2         4.7    87510   8700.0   5000000    0.0  2018      8    1
# 3         4.5   215644  25000.0  50000000    0.0  2018      6    8
# 4         4.3      967   2800.0    100000    0.0  2018      6   20
# ...       ...      ...      ...       ...    ...   ...    ...  ...
# 10835     4.5       38  53000.0      5000    0.0  2017      7   25
# 10836     5.0        4   3600.0       100    0.0  2018      7    6
# 10837     NaN        3   9500.0      1000    0.0  2017      1   20
# 10838     4.5      114      NaN      1000    0.0  2015      1   19
# 10839     4.5   398307  19000.0  10000000    0.0  2018      7   25
#
# [9659 rows x 8 columns]

# %%
df['type'].value_counts(normalize=True)*100
# Out:
# type
# Free    92.172292
# Paid     7.827708
# Name: proportion, dtype: float64

# %%
for col in categorical_features:
    print(f"COLUMN: <-----> {df[col].value_counts(normalize = True)*100}")
    print("====================================")
# Out:
# COLUMN: <-----> app
# Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: proportion, Length: 9659, dtype: float64
# ...
# COLUMN: <-----> category
# FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# ...

# %%
df['type'].value_counts(normalize=True)
# Out:
# type
# Free    0.921723
# Paid    0.078277
# Name: proportion, dtype: float64

# %%
import seaborn as sns

sns.countplot(x= df['type'])
# Out:
# <AxesSubplot: xlabel='type', ylabel='count'>

# %%
sns.countplot(x= df['content_rating'])
# Out:
# <AxesSubplot: xlabel='content_rating', ylabel='count'>

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize = (10,8))
# plt.suptitle("univariate analysis of categorical features", fontsize = 20, fontweight ='bold', alpha = 0.8, y=1.)

# for i in range(len(categorical_features)):
#     plt.subplot(10,10, i+1)
#     sns.countplot(x = df[categorical_features[i]])

# %%
numeric_features
# Out:
# ['rating', 'reviews', 'size', 'installs', 'price', 'year', 'month', 'day']

# %%
sns.kdeplot(df['price'])
# Out:
# <AxesSubplot: xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(df['reviews'])
# Out:
# <AxesSubplot: xlabel='reviews', ylabel='Density'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,8))
plt.suptitle("Univariate analysis of numerical features")

for i in range(0,len(numeric_features)):
    plt.subplot(5,3, i+1)
    sns.kdeplot(df[numeric_features[i]], fill = True)
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %% [markdown]
# Univariate analysis
#
# 1. Most popular category in app

# %%
#Most 
df['category'].value_counts()
# Out:
# category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   56
# ...

# %%
top10 = pd.DataFrame(df['category'].value_counts())[:10]
top10
# Out:
#                  count
# category
# FAMILY            1832
# GAME               959
# TOOLS              827
# BUSINESS           420
# MEDICAL            395
# PERSONALIZATION    376
# PRODUCTIVITY       374
# LIFESTYLE          369
# FINANCE            345
# SPORTS             325

# %%
#which category has largest number of installation
df_cat_installs = df.groupby(df['category'])['installs'].sum().sort_values(ascending=False).reset_index()

top10cat = df_cat_installs[:10]
top10cat
# Out:
#              category     installs
# 0                GAME  13878924415
# 1       COMMUNICATION  11038276251
# 2               TOOLS   8001771915
# 3        PRODUCTIVITY   5793091369
# 4              SOCIAL   5487867902
# 5         PHOTOGRAPHY   4649147655
# 6              FAMILY   4427941505
# 7       VIDEO_PLAYERS   3926902720
# 8    TRAVEL_AND_LOCAL   2894887146
# 9  NEWS_AND_MAGAZINES   2369217760

# %%
sns.barplot(x = 'installs',y='category', data = top10cat)
# Out:
# <AxesSubplot: xlabel='installs', ylabel='category'>

# %% [markdown]
# #### App with most installs

# %%
dfa.sort_values(by = 'installs', ascending=False)[:5]
# Out:
#                 category                            app    installs
# 9311    TRAVEL_AND_LOCAL             Google Street View  1000000000
# 6388  NEWS_AND_MAGAZINES                    Google News  1000000000
# 1145       COMMUNICATION  Skype - free IM & video calls  1000000000
# 9566       VIDEO_PLAYERS                        YouTube  1000000000
# 1181       COMMUNICATION             WhatsApp Messenger  1000000000

# %% [markdown]
# ####  category with most installs

# %%
installs_by_category = dfa.groupby(by = 'category').sum('installs').sort_values(by = 'installs', ascending=False).reset_index()
installs_by_category.head(10)
# Out:
#              category     installs
# 0                GAME  13878924415
# 1       COMMUNICATION  11038276251
# 2               TOOLS   8001771915
# 3        PRODUCTIVITY   5793091369
# 4              SOCIAL   5487867902
# 5         PHOTOGRAPHY   4649147655
# 6              FAMILY   4427941505
# 7       VIDEO_PLAYERS   3926902720
# 8    TRAVEL_AND_LOCAL   2894887146
# 9  NEWS_AND_MAGAZINES   2369217760

# %%
df2 = installs_by_category.head(10)

# %%
sns.barplot(x = df2['installs'], y = df2['category'])
# Out:
# <AxesSubplot: xlabel='installs', ylabel='category'>

# %%
df
# Out:
#                                                      app             category
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN  \
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# #### Top 5 most installed apps in each category

# %%
#5  most instslled apps in each popular categories?

dfa = df.groupby(['category','app'])['installs'].sum().sort_values(ascending = False).reset_index()
dfa
# Out:
#                 category                            app    installs
# 0       TRAVEL_AND_LOCAL             Google Street View  1000000000
# 1     NEWS_AND_MAGAZINES                    Google News  1000000000
# 2          COMMUNICATION  Skype - free IM & video calls  1000000000
# 3          VIDEO_PLAYERS                        YouTube  1000000000
# 4          COMMUNICATION             WhatsApp Messenger  1000000000
# ...                  ...                            ...         ...
# 9654    TRAVEL_AND_LOCAL       EG | Explore Folegandros           0
# 9655             MEDICAL                   EP Cook Book           0
# 9656             FINANCE                    Eu sou Rico           0
# 9657              FAMILY     Ain Arabic Kids Alif Ba ta           0
# 9658  NEWS_AND_MAGAZINES              Sweden Newspapers           0
#
# [9659 rows x 3 columns]

# %%
dfa.sort_values(['installs'], ascending=False)
# Out:
#                 category                            app    installs
# 9311    TRAVEL_AND_LOCAL             Google Street View  1000000000
# 6388  NEWS_AND_MAGAZINES                    Google News  1000000000
# 1145       COMMUNICATION  Skype - free IM & video calls  1000000000
# 9566       VIDEO_PLAYERS                        YouTube  1000000000
# 1181       COMMUNICATION             WhatsApp Messenger  1000000000
# ...                  ...                            ...         ...
# 9275    TRAVEL_AND_LOCAL       EG | Explore Folegandros           0
# 6020             MEDICAL                   EP Cook Book           0
# 3662             FINANCE                    Eu sou Rico           0
# 1797              FAMILY     Ain Arabic Kids Alif Ba ta           0
# 6471  NEWS_AND_MAGAZINES              Sweden Newspapers           0
#
# [9659 rows x 3 columns]

# %%
dfa[dfa['category']=='GAME'].sort_values(by = 'installs', ascending = False)[:5]
# Out:
#      category               app    installs
# 4773     GAME    Subway Surfers  1000000000
# 4628     GAME               Pou   500000000
# 4802     GAME      Temple Run 2   500000000
# 4167     GAME  Candy Crush Saga   500000000
# 4580     GAME    My Talking Tom   500000000

# %%
dfa[dfa['category']=='FAMILY'].sort_values(by = 'installs',ascending = False)[:5]
# Out:
#      category                            app   installs
# 3285   FAMILY                 Talking Ginger  100000000
# 3412   FAMILY         Where's My Water? Free  100000000
# 3333   FAMILY               Tom Loves Angela  100000000
# 3287   FAMILY         Talking Tom & Ben News  100000000
# 1976   FAMILY  Bitmoji – Your Personal Emoji  100000000

# %% [markdown]
# #### How many apps that have 5 star ratings?

# %%
df[df['rating']==5]
# Out:
#                                               app   category  rating  reviews
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0       15  \
# 612                 American Girls Mobile Numbers     DATING     5.0        5
# 615                                  Awake Dating     DATING     5.0        2
# 633                         Spine- The dating app     DATING     5.0        5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0        6
# ...                                           ...        ...     ...      ...
# 10720                           Mad Dash Fo' Cash       GAME     5.0       14
# 10741                       GKPB FP Online Church  LIFESTYLE     5.0       32
# 10775                            Monster Ride Pro       GAME     5.0        1
# 10819                             Fr. Daoud Lamei     FAMILY     5.0       22
# 10836            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0        4
#
# ...

# %% [markdown]
# #### Price vs category

# %%
plt.figure(figsize = (20,10))
sns.scatterplot(x = 'price', y = 'category', data= df)
# Out:
# <AxesSubplot: xlabel='price', ylabel='category'>

# %% [markdown]
# #### Which categry app users are revieweing the most?

# %%
df3 = df.groupby('category').agg(reviews=('reviews', 'sum'), installs=('installs', 'sum')).sort_values(by = 'reviews', ascending = False)
df3['review_rate_%'] = round((df3['reviews']/df3['installs']*100),7)
df3
# Out:
#                        reviews     installs  review_rate_%
# category
# GAME                 622298709  13878924415       4.483767
# COMMUNICATION        285811368  11038276251       2.589275
# TOOLS                229356578   8001771915       2.866322
# SOCIAL               227927801   5487867902       4.153303
# FAMILY               143825488   4427941505       3.248134
# PHOTOGRAPHY          105351270   4649147655       2.266034
# VIDEO_PLAYERS         67484568   3926902720       1.718519
# PRODUCTIVITY          55590649   5793091369       0.959603
# PERSONALIZATION       53543080   1532494782       3.493851
# SHOPPING              44551730   1400348785       3.181474
# SPORTS                35348813   1096474498       3.223861
# ENTERTAINMENT         34762650   2113660000       1.644666
# TRAVEL_AND_LOCAL      26819741   2894887146       0.926452
# NEWS_AND_MAGAZINES    23130228   2369217760       0.976281
# HEALTH_AND_FITNESS    21361355   1144022512       1.867215
# ...

# %%
df.groupby('type').agg({'installs':'sum'})
# Out:
#          installs
# type
# Free  75065572646
# Paid     57364881

# %%
fig, ax = plt.subplots(1,2,figsize=(20,7))
df.value_counts('type').plot.pie(y='type',startangle=90, explode=(0.2,0), title='Percentage of the Free App and Paid App', legend=False, autopct='%.2f', ax=ax[0])
ax[0].set(ylabel='Type of Apps')
df.groupby('type').agg({'installs':sum}).plot.pie(y='installs', startangle=90, explode=(0.2,0), title='Percentage of Installs Number for Free App and Paid App', legend=False, autopct='%.2f', ax=ax[1])
# Out:
# <AxesSubplot: title={'center': 'Percentage of Installs Number for Free App and Paid App'}, ylabel='installs'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="installs",y="rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="category",y="rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation = 90)
sns.barplot('category','size',data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 3
#       1 plt.figure(figsize=(15,15))
#       2 plt.xticks(rotation = 90)
# ----> 3 sns.barplot('category','size',data=df)
#       4 plt.show()
#
# TypeError: barplot() got multiple values for argument 'data'

# %%
plt.subplots(figsize=(20,10))
freq= pd.Series()
freq=df['year'].value_counts()
freq.plot()
plt.xlabel("Dates")
plt.ylabel("Number of updates")
plt.title("Time series plot of Last Updates")
# Out:
# Text(0.5, 1.0, 'Time series plot of Last Updates')

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='rating',data = df,palette="Set1_r")
plt.xticks(rotation =90)
plt.title('Countplot for ratings')             
plt.show()
